-- %% [markdown]
-- # `bronze.trusts` — DDL
--
-- The metadata recast to STRING. Same rows, same columns, nothing rejected.
--
-- Declared here rather than inside the load, so the shape can be read without reading the
-- code that fills it.

-- %%
CREATE TABLE IF NOT EXISTS `index-vs-trust-pipeline`.bronze.trusts (
  trust_name        STRING,
  ticker            STRING,
  aic_sector        STRING,
  source_url        STRING,
  manager           STRING,
  management_group  STRING,
  notes             STRING
)
COMMENT 'landing.trusts_raw recast to STRING';

-- %% [markdown]
-- ## Verification
--
-- Expected: 7 columns.

-- %%
SELECT COUNT(*) AS columns
FROM `index-vs-trust-pipeline`.information_schema.columns
WHERE table_schema = 'bronze' AND table_name = 'trusts';
