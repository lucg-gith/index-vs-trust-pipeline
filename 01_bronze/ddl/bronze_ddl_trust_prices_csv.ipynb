-- %% [markdown]
-- # `bronze.trust_prices_csv` — DDL
--
-- The archive recast to STRING.
--
-- Declared here rather than inside the load, so the shape can be read without reading the
-- code that fills it.

-- %%
CREATE TABLE IF NOT EXISTS `index-vs-trust-pipeline`.bronze.trust_prices_csv (
  trust_name        STRING,
  ticker            STRING,
  aic_sector        STRING,
  date              STRING,
  price_gbx_or_gbp  STRING
)
COMMENT 'landing.trust_prices_csv_raw recast to STRING';

-- %% [markdown]
-- ## Verification
--
-- Expected: 5 columns.

-- %%
SELECT COUNT(*) AS columns
FROM `index-vs-trust-pipeline`.information_schema.columns
WHERE table_schema = 'bronze' AND table_name = 'trust_prices_csv';
