-- %% [markdown]
-- # Gold — schema
--
-- The dimensional model: two dimensions, two facts, both dimensions joining **directly** to
-- both facts. A true star, no snowflaking.
--
-- This step builds the dimensions. The facts are step 6.

-- %%
CREATE SCHEMA IF NOT EXISTS `index-vs-trust-pipeline`.gold
COMMENT 'Dimensional model: dim_date, dim_ticker (SCD2), and the two performance facts';

-- %% [markdown]
-- ## Verification
--
-- Expected: one row, `gold`.

-- %%
SHOW SCHEMAS IN `index-vs-trust-pipeline` LIKE 'gold';
